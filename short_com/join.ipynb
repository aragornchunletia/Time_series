# %%
import pandas as pd

# %%
sheet_dict = pd.read_excel(r"C:\Users\mchun\CN-ML\time_series\short_com\TG51_SNP_INDEX.xlsx", sheet_name=None)

# %%
sheet_dict.keys()
# Out:
# dict_keys(['chr17', 'chr17SNP', 'chr14', 'chr14SNP', 'chr4', 'chr4SNP'])

# %%
for sheet in sheet_dict.keys():
    print(sheet_dict[sheet].columns)
# Out:
# Index(['#CHROM', 'pos', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT',
#        'P1_sorted.bam', 'Pool1_sorted.bam', 'Pool2_sorted.bam'],
#       dtype='object')
# Index(['chr', 'pos', 'type', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')
# Index(['#CHROM', 'pos', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT',
#        'P1_sorted.bam', 'Pool1_sorted.bam', 'Pool2_sorted.bam'],
#       dtype='object')
# Index(['chr', 'pos', 'type', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')
# Index(['#CHROM', 'pos', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT',
#        'P1_sorted.bam', 'Pool1_sorted.bam', 'Pool2_sorted.bam'],
#       dtype='object')
# Index(['chr', 'pos', 'type', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
# ...

# %%
g1 = ['chr17', 'chr17SNP']
g2 = ['chr14', 'chr14SNP']
g3 = ['chr4', 'chr4SNP']

# %%
for sheet in sheet_dict.keys():
    num_rows = sheet_dict[sheet].shape[0]
    unique_pos_values = len(sheet_dict[sheet]["pos"].unique())
    num_duplicates = num_rows - sheet_dict[sheet]["pos"].nunique()  # Count duplicates based on the "pos" column
    
    print(f"{sheet} has len {num_rows} and has unique values {unique_pos_values}. Number of duplicate values is {num_duplicates}.")
# Out:
# chr17 has len 67278 and has unique values 66959. Number of duplicate values is 319.
# chr17SNP has len 3971 and has unique values 3971. Number of duplicate values is 0.
# chr14 has len 70600 and has unique values 70318. Number of duplicate values is 282.
# chr14SNP has len 3436 and has unique values 3436. Number of duplicate values is 0.
# chr4 has len 63155 and has unique values 62900. Number of duplicate values is 255.
# chr4SNP has len 63114 and has unique values 62900. Number of duplicate values is 214.

# %%
g1_0 = set(sheet_dict[g1[0]].pos.unique())
g1_1 = set(sheet_dict[g1[1]].pos.unique())
g2_0 = set(sheet_dict[g2[0]].pos.unique())
g2_1 = set(sheet_dict[g2[1]].pos.unique())
g3_0 = set(sheet_dict[g3[0]].pos.unique())
g3_1 = set(sheet_dict[g3[1]].pos.unique())

# %%
common_pos_g1 = g1_0.intersection(g1_1)
common_pos_g2 = g2_0.intersection(g2_1)
common_pos_g3 = g3_0.intersection(g3_1)

# %%
filtered_df_g1_0 = sheet_dict[g1[0]][sheet_dict[g1[0]]['pos'].isin(common_pos_g1)]
filtered_df_g1_1 = sheet_dict[g1[1]][sheet_dict[g1[1]]['pos'].isin(common_pos_g1)]

# %%
filtered_df_g1_
# Out:
#                                 chr        pos   type  Unnamed: 3  Unnamed: 4  \
# 0     arahy.Tifrunner.gnm1.Arahy.17       8555  indel          16           9
# 1     arahy.Tifrunner.gnm1.Arahy.17      12958  indel          22          15
# 2     arahy.Tifrunner.gnm1.Arahy.17      14419  indel          17          27
# 3     arahy.Tifrunner.gnm1.Arahy.17      63285  indel          24          19
# 4     arahy.Tifrunner.gnm1.Arahy.17      66010  indel          22          37
# ...                             ...        ...    ...         ...         ...
# 3966  arahy.Tifrunner.gnm1.Arahy.17  134607957  indel          30          13
# 3967  arahy.Tifrunner.gnm1.Arahy.17  134659807  indel           9           9
# 3968  arahy.Tifrunner.gnm1.Arahy.17  134808847  indel          30          26
# 3969  arahy.Tifrunner.gnm1.Arahy.17  134861480  indel          13           8
# 3970  arahy.Tifrunner.gnm1.Arahy.17  134906730  indel          37          30
#
# ...

# %%
df_merged = pd.merge(filtered_df_g1_1, filtered_df_g1_0, on='pos', how='outer')
df_merged
# Out:
#                                 chr        pos   type  Unnamed: 3  Unnamed: 4  \
# 0     arahy.Tifrunner.gnm1.Arahy.17       8555  indel          16           9
# 1     arahy.Tifrunner.gnm1.Arahy.17      12958  indel          22          15
# 2     arahy.Tifrunner.gnm1.Arahy.17      14419  indel          17          27
# 3     arahy.Tifrunner.gnm1.Arahy.17      63285  indel          24          19
# 4     arahy.Tifrunner.gnm1.Arahy.17      66010  indel          22          37
# ...                             ...        ...    ...         ...         ...
# 4024  arahy.Tifrunner.gnm1.Arahy.17  134607957  indel          30          13
# 4025  arahy.Tifrunner.gnm1.Arahy.17  134659807  indel           9           9
# 4026  arahy.Tifrunner.gnm1.Arahy.17  134808847  indel          30          26
# 4027  arahy.Tifrunner.gnm1.Arahy.17  134861480  indel          13           8
# 4028  arahy.Tifrunner.gnm1.Arahy.17  134906730  indel          37          30
#
# ...
